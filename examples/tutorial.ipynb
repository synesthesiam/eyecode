# %% [markdown]
# # eyeCode Tutorial

# %%
# %run prelude.ipy
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <function __main__.display_pil_image>

# %%
import os
from eyecode import data, aoi, plot, metrics

if not os.path.exists("output"):
    os.makedirs("output")

# %% [markdown]
# ## Loading Data

# %% [markdown]
# Let's start by loading fixations from the very first trial (experiment 1, trial 1).

# %%
exp_id, trial_id = 1, 1
trial_fixes = data.hansen_2012.all_fixations(exp_id, trial_id)

# %% [markdown]
# We can see that there are 103 fixations in this trial.

# %%
print "Experiment", exp_id, ", Trial", trial_id
print trial_fixes
# Out:
# Experiment 1 , Trial 1
#        exp_id  trial_id     base version        offset_kind  offset_x  \
# 17398       1         1  initvar  onebad  manual experiment         0
# 17399       1         1  initvar  onebad  manual experiment         0
# 17400       1         1  initvar  onebad  manual experiment         0
# 17401       1         1  initvar  onebad  manual experiment         0
# 17402       1         1  initvar  onebad  manual experiment         0
# 17403       1         1  initvar  onebad  manual experiment         0
# 17404       1         1  initvar  onebad  manual experiment         0
# 17405       1         1  initvar  onebad  manual experiment         0
# 17406       1         1  initvar  onebad  manual experiment         0
# 17407       1         1  initvar  onebad  manual experiment         0
# 17408       1         1  initvar  onebad  manual experiment         0
# 17409       1         1  initvar  onebad  manual experiment         0
# 17410       1         1  initvar  onebad  manual experiment         0
# 17411       1         1  initvar  onebad  manual experiment         0
# 17412       1         1  initvar  onebad  manual experiment         0
# 17413       1         1  initvar  onebad  manual experiment         0
# 17414       1         1  initvar  onebad  manual experiment         0
# 17415       1         1  initvar  onebad  manual experiment         0
# 17416       1         1  initvar  onebad  manual experiment         0
# 17417       1         1  initvar  onebad  manual experiment         0
# 17418       1         1  initvar  onebad  manual experiment         0
# 17419       1         1  initvar  onebad  manual experiment         0
# 17420       1         1  initvar  onebad  manual experiment         0
# 17421       1         1  initvar  onebad  manual experiment         0
# 17422       1         1  initvar  onebad  manual experiment         0
# 17423       1         1  initvar  onebad  manual experiment         0
# 17424       1         1  initvar  onebad  manual experiment         0
# 17425       1         1  initvar  onebad  manual experiment         0
# 17426       1         1  initvar  onebad  manual experiment         0
# 17427       1         1  initvar  onebad  manual experiment         0
# 17428       1         1  initvar  onebad  manual experiment         0
# 17429       1         1  initvar  onebad  manual experiment         0
# 17430       1         1  initvar  onebad  manual experiment         0
# 17431       1         1  initvar  onebad  manual experiment         0
# 17432       1         1  initvar  onebad  manual experiment         0
# 17433       1         1  initvar  onebad  manual experiment         0
# 17434       1         1  initvar  onebad  manual experiment         0
# 17435       1         1  initvar  onebad  manual experiment         0
# 17436       1         1  initvar  onebad  manual experiment         0
# 17437       1         1  initvar  onebad  manual experiment         0
# 17438       1         1  initvar  onebad  manual experiment         0
# 17439       1         1  initvar  onebad  manual experiment         0
# 17440       1         1  initvar  onebad  manual experiment         0
# 17441       1         1  initvar  onebad  manual experiment         0
# 17442       1         1  initvar  onebad  manual experiment         0
# 17443       1         1  initvar  onebad  manual experiment         0
# 17444       1         1  initvar  onebad  manual experiment         0
# 17445       1         1  initvar  onebad  manual experiment         0
# 17446       1         1  initvar  onebad  manual experiment         0
# 17447       1         1  initvar  onebad  manual experiment         0
# 17448       1         1  initvar  onebad  manual experiment         0
# 17449       1         1  initvar  onebad  manual experiment         0
# 17450       1         1  initvar  onebad  manual experiment         0
# 17451       1         1  initvar  onebad  manual experiment         0
# 17452       1         1  initvar  onebad  manual experiment         0
# 17453       1         1  initvar  onebad  manual experiment         0
# 17454       1         1  initvar  onebad  manual experiment         0
# 17455       1         1  initvar  onebad  manual experiment         0
# 17456       1         1  initvar  onebad  manual experiment         0
# 17457       1         1  initvar  onebad  manual experiment         0
#           ...       ...      ...     ...                ...       ...
#
#        offset_y hit_kind  start_ms  end_ms  fix_x  fix_y  pupil_left  \
# 17398         0   circle       290     623    230    239        2.93
# 17399         0   circle       680     803    863    291        2.83
# 17400         0   circle       873    1053    144    124        2.82
# 17401         0   circle      1080    1197     54     97        2.63
# 17402         0   circle      1329    1852     67    115        2.64
# 17403         0   circle      1873    2350    120    137        2.89
# 17404         0   circle      2363    2610     93    129        2.99
# 17405         0   circle      2639    2919    211    116        3.00
# 17406         0   circle      3062    3359    180    117        3.01
# 17407         0   circle      3382    3632    246    124        3.01
# 17408         0   circle      3662    3949    123    144        3.01
# 17409         0   circle      3969    4102     82    162        3.00
# 17410         0   circle      4262    4685    113    153        2.98
# 17411         0   circle      4702    4985     86    178        3.03
# 17412         0   circle      5012    5172    141    113        3.06
# 17413         0   circle      5555    5658    102    123        3.12
# 17414         0   circle      5689    5932     37    213        3.17
# 17415         0   circle      5965    6432    117    151        3.10
# 17416         0   circle      6452    6842    104    147        2.93
# 17417         0   circle      6992    7072     97    135        3.05
# 17418         0   circle      7232    7312    108    169        3.12
# 17419         0   circle      7332    7442     76    134        3.12
# 17420         0   circle      7462    7985    108    159        3.06
# 17421         0   circle      7995    8455    127    129        3.15
# 17422         0   circle      8475    8678    191    110        3.15
# 17423         0   circle      8825    9405    129    133        3.04
# 17424         0   circle      9581    9744    100    125        3.14
# 17425         0   circle      9768    9951    148    134        3.15
# 17426         0   circle     10095   10308    158    140        3.16
# 17427         0   circle     10325   10588    174    109        3.17
# 17428         0   circle     10608   10835    125    122        3.17
# 17429         0   circle     10854   11141    109    157        3.11
# 17430         0   circle     11168   11321    128    126        3.22
# 17431         0   circle     11458   11668    124    134        3.16
# 17432         0   circle     11694   11984    220    114        3.17
# 17433         0   circle     12014   12231    103    126        3.09
# 17434         0   circle     12251   12484    144    123        3.06
# 17435         0   circle     12631   12728    118    108        3.17
# 17436         0   circle     13207   13337    188    122        3.26
# 17437         0   circle     13354   13514    144    104        3.27
# 17438         0   circle     13537   14403    108    129        3.17
# 17439         0   circle     14434   14724     79     95        3.16
# 17440         0   circle     14744   14901     70    208        2.89
# 17441         0   circle     14960   15057     99    123        3.19
# 17442         0   circle     15713   16606    164    119        3.20
# 17443         0   circle     16740   17527    211    126        3.16
# 17444         0   circle     17566   17833     92    171        3.17
# 17445         0   circle     17873   18206    242    125        3.25
# 17446         0   circle     18240   18423    256    260        3.18
# 17447         0   circle     18453   18650     97    239        3.11
# 17448         0   circle     18693   18830     14    213        3.12
# 17449         0   circle     18950   19133   1003    231        3.11
# 17450         0   circle     19160   19700   1054    201        3.13
# 17451         0   circle     19716   19863   1020    189        2.89
# 17452         0   circle     22586   22713   1085    290        3.31
# 17453         0   circle     22746   22869   1079    187        3.24
# 17454         0   circle     22889   23106   1038    184        3.00
# 17455         0   circle     23222   23445    104    258        2.81
# 17456         0   circle     23525   23602    932    290        2.87
# 17457         0   circle     23679   23966    121    179        2.99
#             ...      ...       ...     ...    ...    ...         ...
#
#        pupil_right aoi_interface aoi_line   aoi_syntax   aoi_block  \
# 17398         2.85      code box   line 7   whitespace  lines 6-10
# 17399         2.77      code box      NaN          NaN         NaN
# 17400         2.73      code box   line 2  punctuation   lines 1-5
# 17401         2.63      code box   line 1   whitespace   lines 1-5
# 17402         2.64      code box   line 2   identifier   lines 1-5
# 17403         2.84      code box   line 3   whitespace   lines 1-5
# 17404         2.92      code box   line 2     operator   lines 1-5
# 17405         2.92      code box   line 2  punctuation   lines 1-5
# 17406         2.90      code box   line 2   whitespace   lines 1-5
# 17407         2.94      code box   line 2      literal   lines 1-5
# 17408         2.91      code box   line 3   identifier   lines 1-5
# 17409         2.95      code box   line 4      keyword   lines 1-5
# 17410         2.92      code box   line 3   whitespace   lines 1-5
# 17411         2.96      code box   line 4   whitespace   lines 1-5
# 17412         2.98      code box   line 2  punctuation   lines 1-5
# 17413         3.00      code box   line 2     operator   lines 1-5
# 17414         3.02      code box   line 6   whitespace  lines 6-10
# 17415         3.00      code box   line 3   whitespace   lines 1-5
# 17416         2.82      code box   line 3     operator   lines 1-5
# 17417         2.98      code box   line 3     operator   lines 1-5
# 17418         3.00      code box   line 4   identifier   lines 1-5
# 17419         3.01      code box   line 3   identifier   lines 1-5
# 17420         3.01      code box   line 3   whitespace   lines 1-5
# 17421         3.02      code box   line 2   whitespace   lines 1-5
# 17422         3.04      code box   line 2   whitespace   lines 1-5
# 17423         2.94      code box   line 3   identifier   lines 1-5
# 17424         3.03      code box   line 2     operator   lines 1-5
# 17425         3.05      code box   line 3   whitespace   lines 1-5
# 17426         3.05      code box   line 3     operator   lines 1-5
# 17427         3.08      code box   line 2  punctuation   lines 1-5
# 17428         3.05      code box   line 2     operator   lines 1-5
# 17429         3.02      code box   line 3   whitespace   lines 1-5
# 17430         3.08      code box   line 2   whitespace   lines 1-5
# 17431         3.04      code box   line 3   identifier   lines 1-5
# 17432         3.06      code box   line 2  punctuation   lines 1-5
# 17433         3.00      code box   line 2     operator   lines 1-5
# 17434         2.97      code box   line 2  punctuation   lines 1-5
# 17435         3.05      code box   line 2     operator   lines 1-5
# 17436         3.11      code box   line 2   whitespace   lines 1-5
# 17437         3.11      code box   line 2  punctuation   lines 1-5
# 17438         3.06      code box   line 2     operator   lines 1-5
# 17439         3.07      code box   line 2      literal   lines 1-5
# 17440         3.03      code box   line 6      literal  lines 6-10
# 17441         3.06      code box   line 2     operator   lines 1-5
# 17442         3.07      code box   line 2      literal   lines 1-5
# 17443         3.06      code box   line 2  punctuation   lines 1-5
# 17444         3.08      code box   line 4   whitespace   lines 1-5
# 17445         3.11      code box   line 2      literal   lines 1-5
# 17446         3.06      code box   line 7  punctuation  lines 6-10
# 17447         3.03      code box   line 7     operator  lines 6-10
# 17448         3.02      code box   line 6   identifier  lines 6-10
# 17449         3.05      code box      NaN          NaN         NaN
# 17450         3.04    output box      NaN          NaN         NaN
# 17451         2.88    output box      NaN          NaN         NaN
# 17452         3.17    output box      NaN          NaN         NaN
# 17453         3.12    output box      NaN          NaN         NaN
# 17454         2.91    output box      NaN          NaN         NaN
# 17455         2.65      code box   line 7     operator  lines 6-10
# 17456         2.81      code box      NaN          NaN         NaN
# 17457         2.89      code box   line 4   identifier   lines 1-5
#                ...           ...      ...          ...         ...
#
#       aoi_code-grid aoi_whitespace-token
# 17398      cell 5,7             token 26 ...
# 17399           NaN                  NaN ...
# 17400      cell 1,4              token 7 ...
# 17401      cell 0,1              token 2 ...
# 17402      cell 1,1              token 5 ...
# 17403      cell 2,3             token 13 ...
# 17404      cell 1,2              token 6 ...
# 17405      cell 1,6              token 8 ...
# 17406      cell 1,5              token 7 ...
# 17407      cell 1,7              token 9 ...
# 17408      cell 2,3             token 13 ...
# 17409      cell 3,2             token 16 ...
# 17410      cell 2,3             token 12 ...
# 17411      cell 3,2             token 16 ...
# 17412      cell 1,4              token 7 ...
# 17413      cell 1,3              token 6 ...
# 17414      cell 4,0             token 19 ...
# 17415      cell 2,3             token 13 ...
# 17416      cell 2,3             token 12 ...
# 17417      cell 2,2             token 12 ...
# 17418      cell 3,3             token 17 ...
# 17419      cell 2,2             token 11 ...
# 17420      cell 2,3             token 12 ...
# 17421      cell 1,3             token 13 ...
# 17422      cell 1,6              token 8 ...
# 17423      cell 2,3             token 13 ...
# 17424      cell 1,2              token 6 ...
# 17425      cell 2,4              token 7 ...
# 17426      cell 2,4             token 14 ...
# 17427      cell 1,5              token 7 ...
# 17428      cell 1,3              token 6 ...
# 17429      cell 2,3             token 12 ...
# 17430      cell 1,3              token 6 ...
# 17431      cell 2,3             token 13 ...
# 17432      cell 1,6              token 8 ...
# 17433      cell 1,3              token 6 ...
# 17434      cell 1,4              token 7 ...
# 17435      cell 1,3              token 6 ...
# 17436      cell 1,5              token 8 ...
# 17437      cell 1,4              token 7 ...
# 17438      cell 1,3              token 6 ...
# 17439      cell 0,2              token 3 ...
# 17440      cell 4,1             token 20 ...
# 17441      cell 1,2              token 6 ...
# 17442      cell 1,5              token 7 ...
# 17443      cell 1,6              token 8 ...
# 17444      cell 3,2             token 17 ...
# 17445      cell 1,7              token 9 ...
# 17446      cell 6,8             token 26 ...
# 17447      cell 5,2             token 23 ...
# 17448      cell 4,0             token 18 ...
# 17449           NaN                  NaN ...
# 17450           NaN                  NaN ...
# 17451           NaN                  NaN ...
# 17452           NaN                  NaN ...
# 17453           NaN                  NaN ...
# 17454           NaN                  NaN ...
# 17455      cell 6,3             token 23 ...
# 17456           NaN                  NaN ...
# 17457      cell 3,3             token 17 ...
#                 ...                  ...
#
# [103 rows x 29 columns]

# %% [markdown]
# Let's visualize the fixations (and saccades) by loading a screen shot of the trial and plotting fixation circles on it. The circles' radii are proportional to their duration.

# %%
trial_image = data.hansen_2012.trial_screen(exp_id, trial_id)
img = plot.fix_circles(trial_fixes, trial_image)
img.save("output/fix-circles.png")
img
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x5494BD8>

# %% [markdown]
# ## Areas of Interest

# %% [markdown]
# Areas of interest (AOIs) have already been identified, and are available with the data. AOIs are grouped by kind into layers.

# %%
trial_aois = data.hansen_2012.areas_of_interest(exp_id, trial_id)
print "AOI kinds:", trial_aois.kind.unique()
# Out:
# AOI kinds: ['interface' 'syntax' 'line' 'block' 'code-grid' 'whitespace-token'
#  'intuitive']

# %% [markdown]
# AOIs are just named rectangles with an upper-left origin (x, y) and size (width, height).

# %%
trial_aois
# Out:
#          base category  exp_id  height       kind  local_id             name  \
# 9908  initvar      NaN       1    1070  interface       0,0         code box
# 9909  initvar      NaN       1     278  interface   1005,78       output box
# 9910  initvar      NaN       1      26  interface  1005,373  continue button
# 9911  initvar      NaN       1      29     syntax      0,-2       identifier
# 9912  initvar      NaN       1      29     syntax     14,-2       whitespace
# 9913  initvar      NaN       1      29     syntax     28,-2         operator
# 9914  initvar      NaN       1      29     syntax     42,-2       whitespace
# 9915  initvar      NaN       1      29     syntax     56,-2          literal
# 9916  initvar      NaN       1      29       line      0,-2           line 1
# 9917  initvar      NaN       1      29     syntax      0,28          keyword
# 9918  initvar      NaN       1      29     syntax     42,28       whitespace
# 9919  initvar      NaN       1      29     syntax     56,28       identifier
# 9920  initvar      NaN       1      29     syntax     70,28       whitespace
# 9921  initvar      NaN       1      29     syntax     84,28         operator
# 9922  initvar      NaN       1      29     syntax    112,28       whitespace
# 9923  initvar      NaN       1      29     syntax    126,28      punctuation
# 9924  initvar      NaN       1      29     syntax    140,28          literal
# 9925  initvar      NaN       1      29     syntax    154,28      punctuation
# 9926  initvar      NaN       1      29     syntax    168,28       whitespace
# 9927  initvar      NaN       1      29     syntax    182,28          literal
# 9928  initvar      NaN       1      29     syntax    196,28      punctuation
# 9929  initvar      NaN       1      29     syntax    210,28       whitespace
# 9930  initvar      NaN       1      29     syntax    224,28          literal
# 9931  initvar      NaN       1      29     syntax    238,28      punctuation
# 9932  initvar      NaN       1      29     syntax    252,28       whitespace
# 9933  initvar      NaN       1      29     syntax    266,28          literal
# 9934  initvar      NaN       1      29     syntax    280,28      punctuation
# 9935  initvar      NaN       1      29     syntax    294,28      punctuation
# 9936  initvar      NaN       1      29       line      0,28           line 2
# 9937  initvar      NaN       1      29     syntax      0,58      indentation
# 9938  initvar      NaN       1      29     syntax     56,58       identifier
# 9939  initvar      NaN       1      29     syntax     70,58       whitespace
# 9940  initvar      NaN       1      29     syntax     84,58         operator
# 9941  initvar      NaN       1      29     syntax     98,58       whitespace
# 9942  initvar      NaN       1      29     syntax    112,58       identifier
# 9943  initvar      NaN       1      29     syntax    126,58       whitespace
# 9944  initvar      NaN       1      29     syntax    140,58         operator
# 9945  initvar      NaN       1      29     syntax    154,58       whitespace
# 9946  initvar      NaN       1      29     syntax    168,58       identifier
# 9947  initvar      NaN       1      29       line      0,58           line 3
# 9948  initvar      NaN       1      29     syntax      0,88          keyword
# 9949  initvar      NaN       1      29     syntax     70,88       whitespace
# 9950  initvar      NaN       1      29     syntax     84,88       identifier
# 9951  initvar      NaN       1      29       line      0,88           line 4
# 9952  initvar      NaN       1     120      block      0,-2        lines 1-5
# 9953  initvar      NaN       1      29     syntax     0,148       identifier
# 9954  initvar      NaN       1      29     syntax    14,148       whitespace
# 9955  initvar      NaN       1      29     syntax    28,148         operator
# 9956  initvar      NaN       1      29     syntax    42,148       whitespace
# 9957  initvar      NaN       1      29     syntax    56,148          literal
# 9958  initvar      NaN       1      29       line     0,148           line 6
# 9959  initvar      NaN       1      29     syntax     0,178          keyword
# 9960  initvar      NaN       1      29     syntax    42,178       whitespace
# 9961  initvar      NaN       1      29     syntax    56,178       identifier
# 9962  initvar      NaN       1      29     syntax    70,178       whitespace
# 9963  initvar      NaN       1      29     syntax    84,178         operator
# 9964  initvar      NaN       1      29     syntax   112,178       whitespace
# 9965  initvar      NaN       1      29     syntax   126,178      punctuation
# 9966  initvar      NaN       1      29     syntax   140,178          literal
# 9967  initvar      NaN       1      29     syntax   154,178      punctuation
#           ...      ...     ...     ...        ...       ...              ...
#
#      text  trial_id version  width     x    y
# 9908  NaN         1  onebad   1000    10   72
# 9909  NaN         1  onebad    358  1015  150
# 9910  NaN         1  onebad     76  1015  445
# 9911  NaN         1  onebad     14    10   70
# 9912  NaN         1  onebad     14    24   70
# 9913  NaN         1  onebad     14    38   70
# 9914  NaN         1  onebad     14    52   70
# 9915  NaN         1  onebad     14    66   70
# 9916  NaN         1  onebad     70    10   70
# 9917  NaN         1  onebad     42    10  100
# 9918  NaN         1  onebad     14    52  100
# 9919  NaN         1  onebad     14    66  100
# 9920  NaN         1  onebad     14    80  100
# 9921  NaN         1  onebad     28    94  100
# 9922  NaN         1  onebad     14   122  100
# 9923  NaN         1  onebad     14   136  100
# 9924  NaN         1  onebad     14   150  100
# 9925  NaN         1  onebad     14   164  100
# 9926  NaN         1  onebad     14   178  100
# 9927  NaN         1  onebad     14   192  100
# 9928  NaN         1  onebad     14   206  100
# 9929  NaN         1  onebad     14   220  100
# 9930  NaN         1  onebad     14   234  100
# 9931  NaN         1  onebad     14   248  100
# 9932  NaN         1  onebad     14   262  100
# 9933  NaN         1  onebad     14   276  100
# 9934  NaN         1  onebad     14   290  100
# 9935  NaN         1  onebad     14   304  100
# 9936  NaN         1  onebad    308    10  100
# 9937  NaN         1  onebad     56    10  130
# 9938  NaN         1  onebad     14    66  130
# 9939  NaN         1  onebad     14    80  130
# 9940  NaN         1  onebad     14    94  130
# 9941  NaN         1  onebad     14   108  130
# 9942  NaN         1  onebad     14   122  130
# 9943  NaN         1  onebad     14   136  130
# 9944  NaN         1  onebad     14   150  130
# 9945  NaN         1  onebad     14   164  130
# 9946  NaN         1  onebad     14   178  130
# 9947  NaN         1  onebad    182    10  130
# 9948  NaN         1  onebad     70    10  160
# 9949  NaN         1  onebad     14    80  160
# 9950  NaN         1  onebad     14    94  160
# 9951  NaN         1  onebad     98    10  160
# 9952  NaN         1  onebad    308    10   70
# 9953  NaN         1  onebad     14    10  220
# 9954  NaN         1  onebad     14    24  220
# 9955  NaN         1  onebad     14    38  220
# 9956  NaN         1  onebad     14    52  220
# 9957  NaN         1  onebad     14    66  220
# 9958  NaN         1  onebad     70    10  220
# 9959  NaN         1  onebad     42    10  250
# 9960  NaN         1  onebad     14    52  250
# 9961  NaN         1  onebad     14    66  250
# 9962  NaN         1  onebad     14    80  250
# 9963  NaN         1  onebad     28    94  250
# 9964  NaN         1  onebad     14   122  250
# 9965  NaN         1  onebad     14   136  250
# 9966  NaN         1  onebad     14   150  250
# 9967  NaN         1  onebad     14   164  250
#       ...       ...     ...    ...   ...  ...
#
# [248 rows x 13 columns]

# %% [markdown]
# Let's visualize the interface AOIs by drawing their corresponding rectangles on the trial screen shot.

# %%
interface_aois = trial_aois[trial_aois.kind == "interface"]
img = plot.draw_rectangles(interface_aois, trial_image)
img.save("output/aois-interface.png")
img
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x550B050>

# %% [markdown]
# The red rectangle is called the "code box", while the purple and blue rectangles are the "output box" and "continue button" respectively.
#
# We can calculate some AOI-based metrics easily, such as the number of fixations per AOI.

# %%
metrics.fixes_per_aoi(trial_fixes)
# Out:
# kind       name
# block      lines 1-5     47
#            lines 6-10    29
# code-grid  cell 0,1       1
#            cell 0,2       1
#            cell 1,1       1
#            cell 1,2       3
#            cell 1,3       7
#            cell 1,4       4
#            cell 1,5       4
#            cell 1,6       4
#            cell 1,7       2
#            cell 2,2       2
#            cell 2,3       9
#            cell 2,4       2
#            cell 3,2       4
# ...
# whitespace-token  token 23    4
#                   token 24    2
#                   token 25    1
#                   token 26    3
#                   token 27    1
#                   token 29    3
#                   token 3     1
#                   token 30    1
#                   token 31    2
#                   token 32    2
#                   token 5     1
#                   token 6     9
#                   token 7     8
#                   token 8     5
#                   token 9     2
# Length: 100, dtype: int64

# %% [markdown]
# It's easy to here that most of the fixations on interface AOIs were within the code box. Each AOI kind refers to a different layer, so the same fixations are counted in, for example, the "block" and "line" layers.
#
# We can just as easily determine how much time was spent per AOI (i.e., total fixation duration).

# %%
metrics.fixes_ms_per_aoi(trial_fixes)
# Out:
# kind       name
# block      lines 1-5     13586
#            lines 6-10     7671
# code-grid  cell 0,1        117
#            cell 0,2        290
#            cell 1,1        523
#            cell 1,2        507
#            cell 1,3       2123
#            cell 1,4        733
#            cell 1,5       1583
#            cell 1,6       1560
#            cell 1,7        583
#            cell 2,2        190
#            cell 2,3       3644
#            cell 2,4        396
#            cell 3,2        800
# ...
# whitespace-token  token 23    1110
#                   token 24     743
#                   token 25     133
#                   token 26    1496
#                   token 27     227
#                   token 29     736
#                   token 3      290
#                   token 30     163
#                   token 31     353
#                   token 32     590
#                   token 5      523
#                   token 6     2170
#                   token 7     2369
#                   token 8     1690
#                   token 9      583
# Name: duration_ms, Length: 100, dtype: int64

# %% [markdown]
# The "line" AOIs are of special interest. Let's first see what they look like.

# %%
line_aois = trial_aois[trial_aois.kind == "line"]
img = plot.draw_rectangles(line_aois, trial_image)
img.save("output/aois-line.png")
img
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x544C0E0>

# %%
syntax_aois = trial_aois[trial_aois.kind == "syntax"]
img = plot.draw_rectangles(syntax_aois, trial_image)
img.save("output/aois-syntax.png")
img
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x544CCF8>

# %%
block_aois = trial_aois[trial_aois.kind == "block"]
img = plot.draw_rectangles(block_aois, trial_image)
img.save("output/aois-block.png")
img
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x5440B48>

# %% [markdown]
# ### Creating AOIs from Code
#
# You can create AOIs from your own code easily if it was displayed with a monospace font. For example, let's say we have the following Pythong code:

# %%
code = """a = 3
b = 5
print a + b"""

# %% [markdown]
# Using the `aoi.code_to_aois` function, we can obtain AOI rectangles for every *token* and *line* in the source code. The filename parameter is required to properly guess the code's programming language (more on that in a moment).

# %%
aois = aoi.code_to_aois(code, filename="test.py")
aois
# Out:
#       x   y  width  height   kind                            name  \
# 0    -1  -2     13      23  token                    Token.Name 1
# 1    10  -2     13      23  token                    Token.Text 1
# 2    21  -2     13      23  token                Token.Operator 1
# 3    32  -2     13      23  token                    Token.Text 2
# 4    43  -2     13      23  token  Token.Literal.Number.Integer 1
# 5    -1  21     13      23  token                    Token.Name 2
# 6    10  21     13      23  token                    Token.Text 3
# 7    21  21     13      23  token                Token.Operator 2
# 8    32  21     13      23  token                    Token.Text 4
# 9    43  21     13      23  token  Token.Literal.Number.Integer 2
# 10   -1  44     57      23  token                 Token.Keyword 1
# 11   54  44     13      23  token                    Token.Text 5
# 12   65  44     13      23  token                    Token.Name 3
# 13   76  44     13      23  token                    Token.Text 6
# 14   87  44     13      23  token                Token.Operator 3
# 15   98  44     13      23  token                    Token.Text 7
# 16  109  44     13      23  token                    Token.Name 4
# 17   -1  -2     56      23   line                          line 1
# 18   -1  21     56      23   line                          line 2
# 19   -1  44    122      23   line                          line 3
#
#                  text    category local_id
# 0                   a  identifier    -1,-2
# 1                            text    10,-2
# 2                   =    operator    21,-2
# 3                            text    32,-2
# 4                   3     integer    43,-2
# 5                   b  identifier    -1,21
# 6                            text    10,21
# 7                   =    operator    21,21
# 8                            text    32,21
# 9                   5     integer    43,21
# 10              print     keyword    -1,44
# 11                           text    54,44
# 12                  a  identifier    65,44
# 13                           text    76,44
# 14                  +    operator    87,44
# 15                           text    98,44
# 16                  b  identifier   109,44
# 17          a   =   3         NaN    -1,-2
# 18          b   =   5         NaN    -1,21
# 19  print   a   +   b         NaN    -1,44
#
# [20 rows x 9 columns]

# %% [markdown]
# The AOIs above assume a particular font size, padding, and line spacing. Looking at the help for the `code_to_aois` function reveals the details.

# %%
help(aoi.code_to_aois)
# Out:
# Help on function code_to_aois in module eyecode.aoi._aoi:
#
# code_to_aois(code, lexer=None, filename=None, font_size=(11, 18), line_offset=5, padding=(2, 5), offset=(0, 0), token_kind='token', line_kind='line')
#     Creates area of interest (AOI) rectangles from code using Pygments. AOIs
#     are created for every syntactic token and line. A monospace font is
#     assumed.
#
#     Parameters
#     ----------
#     code : str
#         Code with Unix-style newlines ('\n') in any language supported by
#         Pygments. See http://pygments.org/docs/lexers for available languages.
#
#     lexer : pygments.lexer.Lexer, optional
#         A Pygments lexer that will be used to tokenize the code. If None, a
#         filename must be provided to help Pygments guess the language (default:
#         None).
#
#     filename : str, optional
#         A file name with a language-specific extension used to help Pygments
#         guess the code's language. This is required if no lexer is provided
#         (default: None).
#
#     font_size : tuple of int, optional
#         Width and height of the code's monospace font in pixels (default: (11,
#         18)).
#
#     line_offset : int, optional
#         Number of pixels between lines of code (default: 5)
#
#     padding : tuple of int, optional
#         Symmentric horizontal and vertical padding around each AOI rectangle
#         (default: (2, 5)).
#
#     token_kind : str, optional
#         AOI kind for token AOIs in the returned DataFrame (default: 'token').
#
#     line_kind : str, optional
#         AOI kind for line AOIs in the returned DataFrame (default: 'line').
#
#     Returns
#     -------
#     aois : pandas DataFrame
#         DataFrame with one row per AOI rectangle. Has columns x, y, width,
#         height, kind, name.

# %% [markdown]
# By default, we assume a font size of 18 pixels, a line offset of 5 pixels, and a padding of 2x5 pixels (2 horizontal, 5 vertical).
#
# We can see what this code would look like when rendered with the default monospace font using `plot.draw_code`.

# %%
lines = code.split("\n")
img = plot.draw_code(lines, font_size=18, line_offset=5)
img
# Out:
# <PIL.Image.Image image mode=RGB size=122x70 at 0x53920E0>

# %% [markdown]
# The *token* AOI kind represents each lexically-separable chunk of the code. Here are the token AOIs rendered on top of the image above:

# %%
aoi_img = plot.draw_rectangles(aois[aois.kind == "token"], img)
aoi_img.save("output/aois-token.png")
aoi_img
# Out:
# <PIL.Image.Image image mode=RGB size=122x70 at 0x52D0560>

# %% [markdown]
# We also get *line* AOIs out of the `code_to_aois` function.

# %%
plot.draw_rectangles(aois[aois.kind == "line"], img)
# Out:
# <PIL.Image.Image image mode=RGB size=122x70 at 0x53718C0>

# %% [markdown]
# Building on top of these basic AOIs is easy. For example, we could add a new "block" AOI by combining the 3 line AOIs

# %%
names = aois[aois.kind == "line"].name
aois = aoi.combine_aois(aois, "line", names, "block", "block 1")
plot.draw_rectangles(aois[aois.kind == "block"], img)
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.py:1686: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   "DataFrame index.", UserWarning)
# <PIL.Image.Image image mode=RGB size=122x70 at 0x5389998>

# %% [markdown]
# Creating AOIs from code works on any [language that pygments supports](http://pygments.org/docs/lexers/)! Here's a simple Java example:

# %%
code = """package hello;

class Hello {
    public static void main(String[] args) {
        System.out.println("Hello World");
    }
}"""

aois = aoi.code_to_aois(code, filename="hello.java")
lines = code.split("\n")
img = plot.draw_code(lines, font_size=18, line_offset=5)
aoi_img = plot.draw_rectangles(aois[aois.kind == "token"], img)
aoi_img.save("output/aois-java.png")
aoi_img
# Out:
# <PIL.Image.Image image mode=RGB size=485x162 at 0x5394368>

# %% [markdown]
# ## Plotting

# %% [markdown]
# An important question we can answer with these AOIs is: did the programmer read the program from top to bottom? To answer this, let's first get the code from this trial.

# %%
base, version = trial_fixes[["base", "version"]].values[0]
trial_code = "".join(data.hansen_2012.program_code(base, version))
print "Code for", base, version, "program"
print trial_code
# Out:
# Code for initvar onebad program
# a = 1
# for i in [1, 2, 3, 4]:
#     a = a * i
# print a
#
# b = 1
# for i in [1, 2, 3, 4]:
#     b = b + i
# print b

# %% [markdown]
# Next, we can create an image with this code, highlighted using Pygments.

# %%
code_image = plot.highlight_code(trial_code, filename="sample.py", line_numbers=True)
code_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=296x290 at 0x5371F80>

# %% [markdown]
# Next, we'll use the `line_fixations()` data method to get a filtered version of this trial's fixations. These are fixations that:
#
# 1. Occurred on a line
# 2. Have a special `line` property with the 1-based line number

# %%
line_fixes = data.hansen_2012.line_fixations()
trial_line_fixes = line_fixes[(line_fixes.exp_id == exp_id) &
                              (line_fixes.trial_id == trial_id)]
trial_line_fixes
# Out:
#        exp_id  trial_id     base version  offset_x  offset_y  start_ms  \
# 13952       1         1  initvar  onebad         0         0       290
# 13953       1         1  initvar  onebad         0         0       873
# 13954       1         1  initvar  onebad         0         0      1080
# 13955       1         1  initvar  onebad         0         0      1329
# 13956       1         1  initvar  onebad         0         0      1873
# 13957       1         1  initvar  onebad         0         0      2363
# 13958       1         1  initvar  onebad         0         0      2639
# 13959       1         1  initvar  onebad         0         0      3062
# 13960       1         1  initvar  onebad         0         0      3382
# 13961       1         1  initvar  onebad         0         0      3662
# 13962       1         1  initvar  onebad         0         0      3969
# 13963       1         1  initvar  onebad         0         0      4262
# 13964       1         1  initvar  onebad         0         0      4702
# 13965       1         1  initvar  onebad         0         0      5012
# 13966       1         1  initvar  onebad         0         0      5555
# 13967       1         1  initvar  onebad         0         0      5689
# 13968       1         1  initvar  onebad         0         0      5965
# 13969       1         1  initvar  onebad         0         0      6452
# 13970       1         1  initvar  onebad         0         0      6992
# 13971       1         1  initvar  onebad         0         0      7232
# 13972       1         1  initvar  onebad         0         0      7332
# 13973       1         1  initvar  onebad         0         0      7462
# 13974       1         1  initvar  onebad         0         0      7995
# 13975       1         1  initvar  onebad         0         0      8475
# 13976       1         1  initvar  onebad         0         0      8825
# 13977       1         1  initvar  onebad         0         0      9581
# 13978       1         1  initvar  onebad         0         0      9768
# 13979       1         1  initvar  onebad         0         0     10095
# 13980       1         1  initvar  onebad         0         0     10325
# 13981       1         1  initvar  onebad         0         0     10608
# 13982       1         1  initvar  onebad         0         0     10854
# 13983       1         1  initvar  onebad         0         0     11168
# 13984       1         1  initvar  onebad         0         0     11458
# 13985       1         1  initvar  onebad         0         0     11694
# 13986       1         1  initvar  onebad         0         0     12014
# 13987       1         1  initvar  onebad         0         0     12251
# 13988       1         1  initvar  onebad         0         0     12631
# 13989       1         1  initvar  onebad         0         0     13207
# 13990       1         1  initvar  onebad         0         0     13354
# 13991       1         1  initvar  onebad         0         0     13537
# 13992       1         1  initvar  onebad         0         0     14434
# 13993       1         1  initvar  onebad         0         0     14744
# 13994       1         1  initvar  onebad         0         0     14960
# 13995       1         1  initvar  onebad         0         0     15713
# 13996       1         1  initvar  onebad         0         0     16740
# 13997       1         1  initvar  onebad         0         0     17566
# 13998       1         1  initvar  onebad         0         0     17873
# 13999       1         1  initvar  onebad         0         0     18240
# 14000       1         1  initvar  onebad         0         0     18453
# 14001       1         1  initvar  onebad         0         0     18693
# 14002       1         1  initvar  onebad         0         0     23222
# 14003       1         1  initvar  onebad         0         0     23679
# 14004       1         1  initvar  onebad         0         0     23989
# 14005       1         1  initvar  onebad         0         0     24175
# 14006       1         1  initvar  onebad         0         0     28541
# 14007       1         1  initvar  onebad         0         0     28968
# 14008       1         1  initvar  onebad         0         0     29444
# 14009       1         1  initvar  onebad         0         0     29918
# 14010       1         1  initvar  onebad         0         0     30071
# 14011       1         1  initvar  onebad         0         0     30431
#           ...       ...      ...     ...       ...       ...       ...
#
#        end_ms  fix_x  fix_y  pupil_left  pupil_right hit_id_interface  \
# 13952     623    230    239        2.93         2.85              0,0
# 13953    1053    144    124        2.82         2.73              0,0
# 13954    1197     54     97        2.63         2.63              0,0
# 13955    1852     67    115        2.64         2.64              0,0
# 13956    2350    120    137        2.89         2.84              0,0
# 13957    2610     93    129        2.99         2.92              0,0
# 13958    2919    211    116        3.00         2.92              0,0
# 13959    3359    180    117        3.01         2.90              0,0
# 13960    3632    246    124        3.01         2.94              0,0
# 13961    3949    123    144        3.01         2.91              0,0
# 13962    4102     82    162        3.00         2.95              0,0
# 13963    4685    113    153        2.98         2.92              0,0
# 13964    4985     86    178        3.03         2.96              0,0
# 13965    5172    141    113        3.06         2.98              0,0
# 13966    5658    102    123        3.12         3.00              0,0
# 13967    5932     37    213        3.17         3.02              0,0
# 13968    6432    117    151        3.10         3.00              0,0
# 13969    6842    104    147        2.93         2.82              0,0
# 13970    7072     97    135        3.05         2.98              0,0
# 13971    7312    108    169        3.12         3.00              0,0
# 13972    7442     76    134        3.12         3.01              0,0
# 13973    7985    108    159        3.06         3.01              0,0
# 13974    8455    127    129        3.15         3.02              0,0
# 13975    8678    191    110        3.15         3.04              0,0
# 13976    9405    129    133        3.04         2.94              0,0
# 13977    9744    100    125        3.14         3.03              0,0
# 13978    9951    148    134        3.15         3.05              0,0
# 13979   10308    158    140        3.16         3.05              0,0
# 13980   10588    174    109        3.17         3.08              0,0
# 13981   10835    125    122        3.17         3.05              0,0
# 13982   11141    109    157        3.11         3.02              0,0
# 13983   11321    128    126        3.22         3.08              0,0
# 13984   11668    124    134        3.16         3.04              0,0
# 13985   11984    220    114        3.17         3.06              0,0
# 13986   12231    103    126        3.09         3.00              0,0
# 13987   12484    144    123        3.06         2.97              0,0
# 13988   12728    118    108        3.17         3.05              0,0
# 13989   13337    188    122        3.26         3.11              0,0
# 13990   13514    144    104        3.27         3.11              0,0
# 13991   14403    108    129        3.17         3.06              0,0
# 13992   14724     79     95        3.16         3.07              0,0
# 13993   14901     70    208        2.89         3.03              0,0
# 13994   15057     99    123        3.19         3.06              0,0
# 13995   16606    164    119        3.20         3.07              0,0
# 13996   17527    211    126        3.16         3.06              0,0
# 13997   17833     92    171        3.17         3.08              0,0
# 13998   18206    242    125        3.25         3.11              0,0
# 13999   18423    256    260        3.18         3.06              0,0
# 14000   18650     97    239        3.11         3.03              0,0
# 14001   18830     14    213        3.12         3.02              0,0
# 14002   23445    104    258        2.81         2.65              0,0
# 14003   23966    121    179        2.99         2.89              0,0
# 14004   24152     34    213        3.02         2.92              0,0
# 14005   24292     79    177        3.06         2.98              0,0
# 14006   28844     37    223        3.00         2.95              0,0
# 14007   29421     68    259        3.05         2.88              0,0
# 14008   29894    146    267        3.02         2.90              0,0
# 14009   30051    218    280        2.95         2.86              0,0
# 14010   30291    151    291        2.96         2.88              0,0
# 14011   30681    114    299        3.03         2.95              0,0
#           ...    ...    ...         ...          ...              ...
#
#       hit_id_line hit_id_syntax hit_id_block hit_id_code-grid  \
# 13952       0,178       210,178        0,148          210,148
# 13953        0,28        126,28         0,-2           120,28
# 13954        0,-2         42,-2         0,-2            30,-2
# 13955        0,28         56,28         0,-2            30,28
# 13956        0,58         98,58         0,-2            90,58
# 13957        0,28         84,28         0,-2            60,28
# 13958        0,28        196,28         0,-2           180,28
# 13959        0,28        168,28         0,-2           150,28
# 13960        0,28        224,28         0,-2           210,28
# 13961        0,58        112,58         0,-2            90,58
# 13962        0,88          0,88         0,-2            60,88
# 13963        0,58         98,58         0,-2            90,58
# 13964        0,88         70,88         0,-2            60,88
# 13965        0,28        126,28         0,-2           120,28
# 13966        0,28         84,28         0,-2            90,28
# 13967       0,148        14,148        0,148            0,118
# 13968        0,58         98,58         0,-2            90,58
# 13969        0,58         84,58         0,-2            90,58
# 13970        0,58         84,58         0,-2            60,58
# 13971        0,88         84,88         0,-2            90,88
# 13972        0,58         56,58         0,-2            60,58
# 13973        0,58         98,58         0,-2            90,58
# 13974        0,28        112,28         0,-2            90,28
# 13975        0,28        168,28         0,-2           180,28
# 13976        0,58        112,58         0,-2            90,58
# 13977        0,28         84,28         0,-2            60,28
# 13978        0,58        126,58         0,-2           120,58
# 13979        0,58        140,58         0,-2           120,58
# 13980        0,28        154,28         0,-2           150,28
# 13981        0,28         84,28         0,-2            90,28
# 13982        0,58         98,58         0,-2            90,58
# 13983        0,28        112,28         0,-2            90,28
# 13984        0,58        112,58         0,-2            90,58
# 13985        0,28        196,28         0,-2           180,28
# 13986        0,28         84,28         0,-2            90,28
# 13987        0,28        126,28         0,-2           120,28
# 13988        0,28         84,28         0,-2            90,28
# 13989        0,28        168,28         0,-2           150,28
# 13990        0,28        126,28         0,-2           120,28
# 13991        0,28         84,28         0,-2            90,28
# 13992        0,28         56,-2         0,-2            60,-2
# 13993       0,148        56,148        0,148           30,118
# 13994        0,28         84,28         0,-2            60,28
# 13995        0,28        140,28         0,-2           150,28
# 13996        0,28        196,28         0,-2           180,28
# 13997        0,88         70,88         0,-2            60,88
# 13998        0,28        224,28         0,-2           210,28
# 13999       0,178       238,178        0,148          240,178
# 14000       0,178        84,178        0,148           60,148
# 14001       0,148         0,148        0,148            0,118
# 14002       0,178        84,178        0,148           90,178
# 14003        0,88         84,88         0,-2            90,88
# 14004       0,148        14,148        0,148            0,118
# 14005        0,88          0,88         0,-2            60,88
# 14006       0,148        14,148        0,148            0,148
# 14007       0,178        56,178        0,148           30,178
# 14008       0,178       126,178        0,148          120,178
# 14009       0,178       196,178        0,148          180,208
# 14010       0,208       140,208        0,148          120,208
# 14011       0,208        98,208        0,148           90,208
#               ...           ...          ...              ...
#
#       hit_id_whitespace-token hit_id_intuitive  duration_ms
# 13952                 224,178          126,177          333 ...
# 13953                  126,28           126,27          180 ...
# 13954                   28,-2            28,-3          117 ...
# 13955                   56,28            56,27          523 ...
# 13956                  112,58           112,57          477 ...
# 13957                   84,28            84,27          247 ...
# 13958                  182,28           126,27          280 ...
# 13959                  126,28           126,27          297 ...
# 13960                  224,28           126,27          250 ...
# 13961                  112,58           112,57          287 ...
# 13962                    0,88             0,87          133 ...
# 13963                   84,58            84,57          423 ...
# 13964                    0,88             0,87          283 ...
# 13965                  126,28           126,27          160 ...
# 13966                   84,28            84,27          103 ...
# 13967                  28,148           28,147          243 ...
# 13968                  112,58           112,57          467 ...
# 13969                   84,58            84,57          390 ...
# 13970                   84,58            84,57           80 ...
# 13971                   84,88            84,87           80 ...
# 13972                   56,58            56,57          110 ...
# 13973                   84,58            84,87          523 ...
# 13974                  112,58           112,57          460 ...
# 13975                  182,28           126,27          203 ...
# 13976                  112,58           112,57          580 ...
# 13977                   84,28            84,27          163 ...
# 13978                  126,28           126,27          183 ...
# 13979                  140,58           140,57          213 ...
# 13980                  126,28           126,27          263 ...
# 13981                   84,28            84,27          227 ...
# 13982                   84,58            84,57          287 ...
# 13983                   84,28           112,57          153 ...
# 13984                  112,58           112,57          210 ...
# 13985                  182,28           126,27          290 ...
# 13986                   84,28            84,27          217 ...
# 13987                  126,28           126,27          233 ...
# 13988                   84,28            84,27           97 ...
# 13989                  182,28           126,27          130 ...
# 13990                  126,28           126,27          160 ...
# 13991                   84,28            84,27          866 ...
# 13992                   56,-2            56,-3          290 ...
# 13993                  56,148           56,147          157 ...
# 13994                   84,28            84,27           97 ...
# 13995                  126,28           126,27          893 ...
# 13996                  182,28           126,27          787 ...
# 13997                   84,88            84,87          267 ...
# 13998                  224,28           126,27          333 ...
# 13999                 224,178          126,177          183 ...
# 14000                  84,178           84,177          197 ...
# 14001                   0,148            0,147          137 ...
# 14002                  84,178           84,177          223 ...
# 14003                   84,88            84,87          287 ...
# 14004                  28,148           28,147          163 ...
# 14005                    0,88             0,87          117 ...
# 14006                  28,148           28,147          303 ...
# 14007                  56,178           56,177          453 ...
# 14008                 126,178          126,177          450 ...
# 14009                 182,178          126,177          133 ...
# 14010                 140,208          140,207          220 ...
# 14011                  84,208           84,207          250 ...
#                           ...              ...          ...
#
# [73 rows x 21 columns]

# %%
print "Fixated lines"
print trial_line_fixes.line
# Out:
# Fixated lines
# 13952    7
# 13953    2
# 13954    1
# 13955    2
# 13956    3
# 13957    2
# 13958    2
# 13959    2
# 13960    2
# 13961    3
# 13962    4
# 13963    3
# 13964    4
# 13965    2
# 13966    2
# ...
# 14010    8
# 14011    8
# 14012    7
# 14013    7
# 14014    7
# 14015    6
# 14016    8
# 14017    8
# 14018    8
# 14019    8
# 14020    7
# 14021    8
# 14022    8
# 14023    7
# 14024    7
# Name: line, Length: 73, dtype: int64

# %% [markdown]
# Finally, we'll use the `line_code_image` plot function to combine our highlighted code with a bar plot indicating the time of the first fixation on each line.

# %%
options = dict(num_lines=9, bar_height=0.7,
               bar_mult=1.035, image_padding=15)

img = plot.line_code_image(trial_line_fixes, code_image,
                           method="first", **options)
img.save("output/line-code-first.png")
img
# Out:
# <PIL.Image.Image image mode=RGBA size=896x290 at 0x542A998>

# %% [markdown]
# With this plot, we can readily see several things. First, although the programmer started on line 7, they read through mostly from top to bottom. Second, they did not fixate line 8 until later in the trial.
#
# Using a timeline plot, we can confirm this and note that the programmer visited the output box twice before fixating on line 8 (and one more time after).

# %%
output_fixes = trial_fixes[trial_fixes.aoi_interface == "output box"]
ax = plot.fix_timeline(trial_line_fixes, 9, output_fixes=output_fixes)
ax.figure.savefig("output/fix-timeline.png")

# %% [markdown]
# Just as easily, we can find out which lines were fixated on for the most time.

# %%
img = plot.line_code_image(trial_line_fixes, code_image,
                           method="time", **options)
img.save("output/line-code-time.png")
img
# Out:
# <PIL.Image.Image image mode=RGBA size=896x290 at 0x39DABD8>

# %% [markdown]
# An overview of time spent on all AOIs at once can be seen using the `aoi_barplot` function.

# %%
aoi_kinds = ["interface", "line", "syntax", "block"]
ax = plot.aoi_barplot(trial_fixes, method="time", aoi_kinds=aoi_kinds, figsize=(10, 5))
ax.set_title("Total Fixation Time by AOI")

# %% [markdown]
# ## Scanpaths

# %% [markdown]
# Using the `aoi` module, we can create a *scanpath* from the fixated lines. This is essentially a timestamped series of fixated AOIs, sorted by fixation time.

# %%
line_sp = aoi.scanpath_from_fixations(trial_fixes, aoi_names="line", repeats=False)
line_sp
# Out:
# start_ms
# 290         line 7
# 873         line 2
# 1080        line 1
# 1329        line 2
# 1873        line 3
# 2363        line 2
# 3662        line 3
# 3969        line 4
# 4262        line 3
# 4702        line 4
# 5012        line 2
# 5689        line 6
# 5965        line 3
# 7232        line 4
# 7332        line 3
# 7995        line 2
# 8825        line 3
# 9581        line 2
# 9768        line 3
# 10325       line 2
# 10854       line 3
# 11168       line 2
# 11458       line 3
# 11694       line 2
# 14744       line 6
# 14960       line 2
# 17566       line 4
# 17873       line 2
# 18240       line 7
# 18693       line 6
# 23222       line 7
# 23679       line 4
# 23989       line 6
# 24175       line 4
# 28541       line 6
# 28968       line 7
# 30071       line 8
# 30834       line 7
# 31707       line 6
# 32030       line 8
# 34057       line 7
# 35053       line 8
# 35810       line 7
# Name: aoi_line, dtype: object

# %% [markdown]
# We can compute a transition matrix between pairs of fixated lines using the `transition_matrix` function. Note that repeated fixations on the same line were excluded from the scanpath (using the `repeats=False` option).

# %%
line_tm = aoi.transition_matrix(line_sp)
line_tm
# Out:
# array([[ 0.        ,  1.        ,  0.        ,  0.        ,  0.        ,
#          0.        ,  0.        ],
#        [ 0.09090909,  0.        ,  0.54545455,  0.09090909,  0.18181818,
#          0.09090909,  0.        ],
#        [ 0.        ,  0.66666667,  0.        ,  0.33333333,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.33333333,  0.33333333,  0.        ,  0.33333333,
#          0.        ,  0.        ],
#        [ 0.        ,  0.16666667,  0.16666667,  0.16666667,  0.        ,
#          0.33333333,  0.16666667],
#        [ 0.        ,  0.16666667,  0.        ,  0.16666667,  0.33333333,
#          0.        ,  0.33333333],
#        [ 0.        ,  0.        ,  0.        ,  0.        ,  0.        ,
#          1.        ,  0.        ]])

# %% [markdown]
# Plotting the transition matrix, it's easy to see that line 1 -> line 2 and line 7 -> line 6 are the most common transitions in this trial.

# %%
name_map = { i : "line {0}".format(i+1) for i in range(9) }
ax = plot.aoi_transitions(line_tm, name_map=name_map, figsize=(10, 8), show_probs=False)
ax.figure.savefig("output/aoi-transitions.png")

# %% [markdown]
# ## Metrics

# %%
all_fixes = data.hansen_2012.all_fixations()

# %% [markdown]
# ### Fixation Duration and Count

# %%
fix_durations = metrics.fixes_ms_per_trial(all_fixes)
print "Mean fixation duration (by trial): {0:.2f} ms".format(fix_durations.mean())
# Out:
# Mean fixation duration (by trial): 280.41 ms

# %%
ax = fix_durations.hist()
ax.set_title("Mean Fixation Durations by Trial")
ax.set_xlabel("Mean Fixation Duration (ms)")
ax.set_ylabel("Count (trials)")

# %%
fixes_per_trial = metrics.fixes_per_trial(all_fixes)
print "Mean Fixation Count:", int(fixes_per_trial.mean())
# Out:
# Mean Fixation Count: 172

# %%
ax = fixes_per_trial.hist(color="r")
ax.set_title("Fixation Counts by Trial")
ax.set_xlabel("Number of Fixations")
ax.set_ylabel("Count (trials")

# %% [markdown]
# ### Saccades and Scanpaths

# %%
all_saccs = data.hansen_2012.all_saccades()
trial_saccs = all_saccs[all_saccs.trial_id == trial_id]
trial_saccs
# Out:
#        exp_id  trial_id     base version  start_ms  end_ms  sacc_x1  sacc_y1  \
# 35311       1         1  initvar  onebad       263     286       87      215
# 35312       1         1  initvar  onebad       623     676      226      240
# 35313       1         1  initvar  onebad       803     853      863      293
# 35314       1         1  initvar  onebad       863     870      114      114
# 35315       1         1  initvar  onebad      1053    1076      147      121
# 35316       1         1  initvar  onebad      1196    1200       56      113
# 35317       1         1  initvar  onebad      1306    1326       43       61
# 35318       1         1  initvar  onebad      1853    1869       67      116
# 35319       1         1  initvar  onebad      2349    2359      127      127
# 35320       1         1  initvar  onebad      2609    2636       93      129
# 35321       1         1  initvar  onebad      2919    2926      202      132
# 35322       1         1  initvar  onebad      3032    3039      165       99
# 35323       1         1  initvar  onebad      3046    3059      172       87
# 35324       1         1  initvar  onebad      3359    3379      180      114
# 35325       1         1  initvar  onebad      3632    3659      246      123
# 35326       1         1  initvar  onebad      3949    3966      124      140
# 35327       1         1  initvar  onebad      4102    4109       78      174
# 35328       1         1  initvar  onebad      4242    4259      106       93
# 35329       1         1  initvar  onebad      4686    4699      115      153
# 35330       1         1  initvar  onebad      4985    5009       86      178
# 35331       1         1  initvar  onebad      5172    5195      133      128
# 35332       1         1  initvar  onebad      5202    5232       71      483
# 35333       1         1  initvar  onebad      5242    5249       92      165
# 35334       1         1  initvar  onebad      5302    5312       97      159
# 35335       1         1  initvar  onebad      5542    5552      122      175
# 35336       1         1  initvar  onebad      5659    5685      105      125
# 35337       1         1  initvar  onebad      5932    5962       37      215
# 35338       1         1  initvar  onebad      6432    6449      120      158
# 35339       1         1  initvar  onebad      6842    6852      102      174
# 35340       1         1  initvar  onebad      6962    6972       78      148
# 35341       1         1  initvar  onebad      6978    6988       91      109
# 35342       1         1  initvar  onebad      7072    7085       92      141
# 35343       1         1  initvar  onebad      7218    7228       99      209
# 35344       1         1  initvar  onebad      7312    7328      109      167
# 35345       1         1  initvar  onebad      7442    7458       78      132
# 35346       1         1  initvar  onebad      7985    7992      105      160
# 35347       1         1  initvar  onebad      8455    8471      128      126
# 35348       1         1  initvar  onebad      8678    8681      183      126
# 35349       1         1  initvar  onebad      8795    8801      107      120
# 35350       1         1  initvar  onebad      8808    8821      121      109
# 35351       1         1  initvar  onebad      9405    9421      136      127
# 35352       1         1  initvar  onebad      9478    9495       95      126
# 35353       1         1  initvar  onebad      9548    9551      132      157
# 35354       1         1  initvar  onebad      9575    9578      100      124
# 35355       1         1  initvar  onebad      9745    9765       99      128
# 35356       1         1  initvar  onebad      9951    9958      144      149
# 35357       1         1  initvar  onebad     10075   10091      152      100
# 35358       1         1  initvar  onebad     10308   10321      157      140
# 35359       1         1  initvar  onebad     10588   10604      169      109
# 35360       1         1  initvar  onebad     10834   10851      123      116
# 35361       1         1  initvar  onebad     11141   11164      110      156
# 35362       1         1  initvar  onebad     11321   11434      121      140
# 35363       1         1  initvar  onebad     11441   11454      119      108
# 35364       1         1  initvar  onebad     11668   11691      122      132
# 35365       1         1  initvar  onebad     11984   12011      223      113
# 35366       1         1  initvar  onebad     12231   12247      109      123
# 35367       1         1  initvar  onebad     12484   12491      135      139
# 35368       1         1  initvar  onebad     12597   12604      107      103
# 35369       1         1  initvar  onebad     12614   12627      114       78
# 35370       1         1  initvar  onebad     12727   12741      113      115
#           ...       ...      ...     ...       ...     ...      ...      ...
#
#        sacc_x2  sacc_y2  duration_ms  dist_euclid
# 35311      222      232           23   136.066160
# 35312      884      296           53   660.378679
# 35313       99      122           50   782.902931
# 35314      125      115            7    11.045361
# 35315       59      106           23    89.269256
# 35316       59      108            4     5.830952
# 35317       61      118           20    59.774577
# 35318      121      136           16    57.584720
# 35319       84      129           10    43.046487
# 35320      205      114           27   113.000000
# 35321      195      110            7    23.086793
# 35322      168       65            7    34.132096
# 35323      175      122           13    35.128336
# 35324      255      124           20    75.663730
# 35325      129      147           27   119.436175
# 35326       83      162           17    46.529560
# 35327       79      140            7    34.014703
# 35328      114      150           17    57.558666
# 35329       75      172           13    44.283180
# 35330      127      120           24    71.028163
# 35331       62      429           23   309.260408
# 35332       94      155           30   328.805414
# 35333      100      182            7    18.788294
# 35334       70      260           10   104.546640
# 35335      100      115           10    63.906181
# 35336       38      203           26   102.825094
# 35337      123      149           30   108.406642
# 35338       87      125           17    46.669048
# 35339       85      189           10    22.671568
# 35340       94      103           10    47.759816
# 35341       98      140           10    31.780497
# 35342       67      158           13    30.232433
# 35343      109      166           10    44.147480
# 35344       72      135           16    48.918299
# 35345      115      169           16    52.325902
# 35346      101      137            7    23.345235
# 35347      197      105           16    72.124892
# 35348      187      114            3    12.649111
# 35349      116      104            6    18.357560
# 35350      125      147           13    38.209946
# 35351       92      129           16    44.045431
# 35352      133      159           17    50.328918
# 35353      131      158            3     1.414214
# 35354      101      126            3     2.236068
# 35355      154      133           20    55.226805
# 35356      135      113            7    37.107951
# 35357      156      144           16    44.181444
# 35358      177      111           13    35.227830
# 35359      120      125           16    51.546096
# 35360       98      158           17    48.877398
# 35361      135      121           23    43.011626
# 35362      117       97          113    43.185646
# 35363      126      144           13    36.674242
# 35364      210      118           23    89.106678
# 35365      113      124           27   110.548632
# 35366      145      121           16    36.055513
# 35367      125      119            7    22.360680
# 35368      113       76            7    27.658633
# 35369      120      115           13    37.483330
# 35370       91      168           14    57.384667
#            ...      ...          ...          ...
#
# [148 rows x 12 columns]

# %%
print "Saccade proportion:", metrics.fixation_saccade_proportion(trial_fixes, trial_saccs)
# Out:
# Saccade proportion: 8.46653084983

# %%
ax = metrics.fixation_saccade_proportion(all_fixes, all_saccs, group_col=["exp_id", "trial_id"])\
    .hist(color="g")
ax.set_title("Duration Proportion of Fixations/Saccades by Trial")
ax.set_xlabel("Fixation/Saccade Duration Proportion")
ax.set_ylabel("Count (trials)")

# %%
print "Scanpath length: {0:,} px".format(int(metrics.scanpath_length(trial_fixes)))
# Out:
# Scanpath length: 2,302,704 px

# %%
print "Convex hull area:", metrics.convex_hull_area(trial_fixes)
print "Convex hull envelope:", metrics.convex_hull_envelope(trial_fixes)
# Out:
# Convex hull area:
# 342744.5
# Convex hull envelope: (14.0, 95.0, 1366.0, 452.0)

# %%
tm = aoi.transition_matrix(line_sp, norm=False)
print "Transition density:", metrics.transition_density(tm)
# Out:
# Transition density: 0.428571428571

# %%
print "Avg. Saccade Length: {0} px".format(metrics.avg_saccade_length(trial_saccs))
# Out:
# Avg. Saccade Length: 153.249622567 px

# %% [markdown]
# ### Spatial Density

# %%
print "Spatial density:", metrics.spatial_density(trial_fixes)
# Out:
# Spatial density: 0.24

# %%
code_box = trial_aois[trial_aois.name == "code box"]
code_box
# Out:
#          base category  exp_id  height       kind local_id      name text  \
# 9908  initvar      NaN       1    1070  interface      0,0  code box  NaN
#
#       trial_id version  width   x   y
# 9908         1  onebad   1000  10  72
#
# [1 rows x 13 columns]

# %%
plot.draw_rectangles(code_box, trial_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0xACE8680>

# %%
lines_box
# Out:
#    x   y  width  height  kind       name
# 0  5  65    318     279  code  lines box
#
# [1 rows x 6 columns]

# %%
lines_box = aoi.envelope(trial_aois[trial_aois.kind == "line"],
                         padding=10, kind="code", name="lines box")
plot.draw_rectangles(lines_box, trial_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x5431950>

# %%
raw_fixes = data.hansen_2012.raw_fixations()
trial_raw_fixes = raw_fixes[(raw_fixes.exp_id == exp_id) &
                            (raw_fixes.trial_id == trial_id)]
code_fixes = aoi.hit_test(trial_raw_fixes, lines_box)
code_fixes
# Out:
#     exp_id  trial_id  start_ms  end_ms  fix_x  fix_y  duration_ms offset_kind  \
# 0        1         1       290     623    230    239          333        none
# 1        1         1       680     803    863    291          123        none
# 2        1         1       873    1053    144    124          180        none
# 3        1         1      1080    1197     54     97          117        none
# 4        1         1      1329    1852     67    115          523        none
# 5        1         1      1873    2350    120    137          477        none
# 6        1         1      2363    2610     93    129          247        none
# 7        1         1      2639    2919    211    116          280        none
# 8        1         1      3062    3359    180    117          297        none
# 9        1         1      3382    3632    246    124          250        none
# 10       1         1      3662    3949    123    144          287        none
# 11       1         1      3969    4102     82    162          133        none
# 12       1         1      4262    4685    113    153          423        none
# 13       1         1      4702    4985     86    178          283        none
# 14       1         1      5012    5172    141    113          160        none
# 15       1         1      5555    5658    102    123          103        none
# 16       1         1      5689    5932     37    213          243        none
# 17       1         1      5965    6432    117    151          467        none
# 18       1         1      6452    6842    104    147          390        none
# 19       1         1      6992    7072     97    135           80        none
# 20       1         1      7232    7312    108    169           80        none
# 21       1         1      7332    7442     76    134          110        none
# 22       1         1      7462    7985    108    159          523        none
# 23       1         1      7995    8455    127    129          460        none
# 24       1         1      8475    8678    191    110          203        none
# 25       1         1      8825    9405    129    133          580        none
# 26       1         1      9581    9744    100    125          163        none
# 27       1         1      9768    9951    148    134          183        none
# 28       1         1     10095   10308    158    140          213        none
# 29       1         1     10325   10588    174    109          263        none
# 30       1         1     10608   10835    125    122          227        none
# 31       1         1     10854   11141    109    157          287        none
# 32       1         1     11168   11321    128    126          153        none
# 33       1         1     11458   11668    124    134          210        none
# 34       1         1     11694   11984    220    114          290        none
# 35       1         1     12014   12231    103    126          217        none
# 36       1         1     12251   12484    144    123          233        none
# 37       1         1     12631   12728    118    108           97        none
# 38       1         1     13207   13337    188    122          130        none
# 39       1         1     13354   13514    144    104          160        none
# 40       1         1     13537   14403    108    129          866        none
# 41       1         1     14434   14724     79     95          290        none
# 42       1         1     14744   14901     70    208          157        none
# 43       1         1     14960   15057     99    123           97        none
# 44       1         1     15713   16606    164    119          893        none
# 45       1         1     16740   17527    211    126          787        none
# 46       1         1     17566   17833     92    171          267        none
# 47       1         1     17873   18206    242    125          333        none
# 48       1         1     18240   18423    256    260          183        none
# 49       1         1     18453   18650     97    239          197        none
# 50       1         1     18693   18830     14    213          137        none
# 51       1         1     18950   19133   1003    231          183        none
# 52       1         1     19160   19700   1054    201          540        none
# 53       1         1     19716   19863   1020    189          147        none
# 54       1         1     22586   22713   1085    290          127        none
# 55       1         1     22746   22869   1079    187          123        none
# 56       1         1     22889   23106   1038    184          217        none
# 57       1         1     23222   23445    104    258          223        none
# 58       1         1     23525   23602    932    290           77        none
# 59       1         1     23679   23966    121    179          287        none
#        ...       ...       ...     ...    ...    ...          ...         ...
#
#      aoi_code
# 0   lines box
# 1         NaN
# 2   lines box
# 3   lines box
# 4   lines box
# 5   lines box
# 6   lines box
# 7   lines box
# 8   lines box
# 9   lines box
# 10  lines box
# 11  lines box
# 12  lines box
# 13  lines box
# 14  lines box
# 15  lines box
# 16  lines box
# 17  lines box
# 18  lines box
# 19  lines box
# 20  lines box
# 21  lines box
# 22  lines box
# 23  lines box
# 24  lines box
# 25  lines box
# 26  lines box
# 27  lines box
# 28  lines box
# 29  lines box
# 30  lines box
# 31  lines box
# 32  lines box
# 33  lines box
# 34  lines box
# 35  lines box
# 36  lines box
# 37  lines box
# 38  lines box
# 39  lines box
# 40  lines box
# 41  lines box
# 42  lines box
# 43  lines box
# 44  lines box
# 45  lines box
# 46  lines box
# 47  lines box
# 48  lines box
# 49  lines box
# 50  lines box
# 51        NaN
# 52        NaN
# 53        NaN
# 54        NaN
# 55        NaN
# 56        NaN
# 57  lines box
# 58        NaN
# 59  lines box
#           ...
#
# [103 rows x 9 columns]

# %%
code_fixes = code_fixes.dropna(subset=["aoi_code"])
code_fixes
# Out:
#     exp_id  trial_id  start_ms  end_ms  fix_x  fix_y  duration_ms offset_kind  \
# 0        1         1       290     623    230    239          333        none
# 2        1         1       873    1053    144    124          180        none
# 3        1         1      1080    1197     54     97          117        none
# 4        1         1      1329    1852     67    115          523        none
# 5        1         1      1873    2350    120    137          477        none
# 6        1         1      2363    2610     93    129          247        none
# 7        1         1      2639    2919    211    116          280        none
# 8        1         1      3062    3359    180    117          297        none
# 9        1         1      3382    3632    246    124          250        none
# 10       1         1      3662    3949    123    144          287        none
# 11       1         1      3969    4102     82    162          133        none
# 12       1         1      4262    4685    113    153          423        none
# 13       1         1      4702    4985     86    178          283        none
# 14       1         1      5012    5172    141    113          160        none
# 15       1         1      5555    5658    102    123          103        none
# 16       1         1      5689    5932     37    213          243        none
# 17       1         1      5965    6432    117    151          467        none
# 18       1         1      6452    6842    104    147          390        none
# 19       1         1      6992    7072     97    135           80        none
# 20       1         1      7232    7312    108    169           80        none
# 21       1         1      7332    7442     76    134          110        none
# 22       1         1      7462    7985    108    159          523        none
# 23       1         1      7995    8455    127    129          460        none
# 24       1         1      8475    8678    191    110          203        none
# 25       1         1      8825    9405    129    133          580        none
# 26       1         1      9581    9744    100    125          163        none
# 27       1         1      9768    9951    148    134          183        none
# 28       1         1     10095   10308    158    140          213        none
# 29       1         1     10325   10588    174    109          263        none
# 30       1         1     10608   10835    125    122          227        none
# 31       1         1     10854   11141    109    157          287        none
# 32       1         1     11168   11321    128    126          153        none
# 33       1         1     11458   11668    124    134          210        none
# 34       1         1     11694   11984    220    114          290        none
# 35       1         1     12014   12231    103    126          217        none
# 36       1         1     12251   12484    144    123          233        none
# 37       1         1     12631   12728    118    108           97        none
# 38       1         1     13207   13337    188    122          130        none
# 39       1         1     13354   13514    144    104          160        none
# 40       1         1     13537   14403    108    129          866        none
# 41       1         1     14434   14724     79     95          290        none
# 42       1         1     14744   14901     70    208          157        none
# 43       1         1     14960   15057     99    123           97        none
# 44       1         1     15713   16606    164    119          893        none
# 45       1         1     16740   17527    211    126          787        none
# 46       1         1     17566   17833     92    171          267        none
# 47       1         1     17873   18206    242    125          333        none
# 48       1         1     18240   18423    256    260          183        none
# 49       1         1     18453   18650     97    239          197        none
# 50       1         1     18693   18830     14    213          137        none
# 57       1         1     23222   23445    104    258          223        none
# 59       1         1     23679   23966    121    179          287        none
# 60       1         1     23989   24152     34    213          163        none
# 61       1         1     24175   24292     79    177          117        none
# 70       1         1     28344   28514    147    188          170        none
# 71       1         1     28541   28844     37    223          303        none
# 72       1         1     28968   29421     68    259          453        none
# 73       1         1     29444   29894    146    267          450        none
# 74       1         1     29918   30051    218    280          133        none
# 75       1         1     30071   30291    151    291          220        none
#        ...       ...       ...     ...    ...    ...          ...         ...
#
#      aoi_code
# 0   lines box
# 2   lines box
# 3   lines box
# 4   lines box
# 5   lines box
# 6   lines box
# 7   lines box
# 8   lines box
# 9   lines box
# 10  lines box
# 11  lines box
# 12  lines box
# 13  lines box
# 14  lines box
# 15  lines box
# 16  lines box
# 17  lines box
# 18  lines box
# 19  lines box
# 20  lines box
# 21  lines box
# 22  lines box
# 23  lines box
# 24  lines box
# 25  lines box
# 26  lines box
# 27  lines box
# 28  lines box
# 29  lines box
# 30  lines box
# 31  lines box
# 32  lines box
# 33  lines box
# 34  lines box
# 35  lines box
# 36  lines box
# 37  lines box
# 38  lines box
# 39  lines box
# 40  lines box
# 41  lines box
# 42  lines box
# 43  lines box
# 44  lines box
# 45  lines box
# 46  lines box
# 47  lines box
# 48  lines box
# 49  lines box
# 50  lines box
# 57  lines box
# 59  lines box
# 60  lines box
# 61  lines box
# 70  lines box
# 71  lines box
# 72  lines box
# 73  lines box
# 74  lines box
# 75  lines box
#           ...
#
# [76 rows x 9 columns]

# %%
plot.fix_circles(code_fixes, trial_image)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0xAD15638>

# %%
print "Spatial density (code):", metrics.spatial_density(code_fixes, grid_bbox=lines_box)
# Out:
# Spatial density (code): 0.35

# %% [markdown]
# ### Reading Order

# %%
first_fixes = metrics.first_fix_ms_aoi(trial_fixes)
first_fixes
# Out:
# kind       name
# interface  code box             290
#            continue button    27108
#            output box         19160
# line       line 1              1080
#            line 2               873
#            line 3              1873
#            line 4              3969
#            line 6              5689
#            line 7               290
#            line 8             30071
# syntax     identifier          1329
#            keyword             3969
#            literal             3382
#            operator            2363
#            punctuation          873
# ...
# intuitive  Token.Name 11            35053
#            Token.Name 2              1329
#            Token.Name 3              7332
#            Token.Name 4              1873
#            Token.Name 6              7232
#            Token.Name 7             18693
#            Token.Name 8             28968
#            Token.Operator 1          1080
#            Token.Operator 2          4262
#            Token.Operator 3         10095
#            Token.Operator 4          5689
#            Token.Operator 5         30431
#            Token.Operator 6         30071
#            Token.Operator.Word 1     2363
#            Token.Operator.Word 2    18453
# Name: start_ms, Length: 100, dtype: int64

# %%
first_lines = first_fixes.loc["line"]
ax = first_lines.plot(kind="bar", color="purple")
ax.set_title("First Fixation Times on Lines")
ax.set_xlabel("Line")
ax.set_ylabel("First Fixation Time (ms)")

# %%
first_lines_out = first_fixes[["interface", "line"]]\
    .drop(["code box", "continue button"], level=1)
ax = first_lines_out.plot(kind="bar", color="orange")
ax.set_title("First Fixation Times on Lines and Output Box")
ax.set_xticklabels(first_lines_out.index.get_level_values("name"))
ax.set_xlabel("Line")
ax.set_ylabel("First Fixation Time (ms)")

# %% [markdown]
# ## Rolling Metrics

# %%
rw1 = metrics.rolling_window(trial_saccs, metrics.avg_saccade_length, 1000, 500).dropna()
rw2 = metrics.rolling_window(trial_fixes, metrics.avg_fixation_duration, 1000, 500).dropna()
rw = rw1.join(rw2, lsuffix="_sacc", rsuffix="_fix")
rw
# Out:
#        value_sacc    value_fix
# 500    397.598283   212.000000
# 1000   268.200293   255.200000
# 1500    53.114876   324.250000
# 2000    50.315603   415.666667
# 2500    59.711093   334.666667
# 3000    56.202191   268.500000
# 3500    62.177980   241.750000
# 4000    64.384776   273.250000
# 4500    51.721178   279.666667
# 5000   146.118683   288.666667
# 5500   138.445855   243.250000
# 6000    80.451741   300.750000
# 6500    37.220232   312.333333
# 7000    39.690856   236.600000
# 7500    39.793870   250.600000
# 8000    47.735063   395.333333
# 8500    35.335377   414.333333
# 9000    32.718193   391.500000
# 9500    31.726564   308.666667
# 10000   29.232385   205.500000
# 10500   44.958192   247.500000
# 11000   44.659001   228.000000
# 11500   64.505365   235.000000
# 12000   64.517876   237.500000
# 12500   48.581909   182.333333
# 13000   46.521906   129.000000
# 13500   64.984413   385.333333
# 14000   58.942991   438.666667
# 14500   67.276870   352.500000
# 15000   70.263856   181.333333
# 15500   66.844977   495.000000
# 16500  226.849335   840.000000
# 17000  226.849335   840.000000
# 17500  150.437123   462.333333
# 18000  148.510391   353.400000
# 18500  213.532158   206.600000
# 19000  210.013548   264.250000
# 19500  137.225774   290.000000
# 20000  176.576911   343.500000
# 22500   82.518338   155.666667
# 23000  497.072210   172.500000
# 23500  556.580817   193.400000
# 24000  407.660632   155.400000
# 24500  271.286748   447.250000
# 25000   57.008771   754.500000
# 25500  862.002320  1376.000000
# 26000  862.002320  1376.000000
# 26500   38.948684   227.000000
# 27000  224.533045   219.250000
# 27500  284.106655   250.000000
# 28000  313.338777   220.750000
# 28500  245.534042   327.250000
# 29000   79.952106   344.000000
# 29500   70.820319   345.333333
# 30000  111.484344   263.250000
# 30500  101.378074   224.000000
# 31000   66.329875   233.250000
# 31500   60.145232   245.750000
# 32000  128.627275   205.750000
# 32500  118.541046   195.200000
#               ...          ...
#
# [77 rows x 2 columns]

# %%
ax = plot.rolling_metrics(rw, ["value_sacc", "value_fix"],
                          names=["Avg. Saccade Length", "Avg. Fixation Duration"],
                          figsize=(10, 5))
ax.grid()
ax.set_title("Rolling Metrics for Experiment {0} Trial {1}".format(exp_id, trial_id))

# %%
from eyecode import util

# %%
resps = util.filter_trial(data.hansen_2012.trial_responses(), exp_id, trial_id)
resps
# Out:
#     exp_id  trial_id     base version  time_ms  response
# 0        1         1  initvar  onebad    21200         a
# 1        1         1  initvar  onebad    22382        a=
# 2        1         1  initvar  onebad    22903       a=2
# 3        1         1  initvar  onebad    23031      a=24
# 4        1         1  initvar  onebad    25318         2
# 5        1         1  initvar  onebad    25590        23
# 6        1         1  initvar  onebad    26998        24
# 7        1         1  initvar  onebad    28231      24\n
# 8        1         1  initvar  onebad    38262     24\n1
# 9        1         1  initvar  onebad    38502    24\n11
# 10       1         1  initvar  onebad    40078  24\n11\n
#
# [11 rows x 6 columns]
